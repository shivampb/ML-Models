# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset/ETH-USD.csv")
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2015-08-08  2.793760  2.798810  0.714725  0.753325   0.753325   674188.0
# 1  2015-08-09  0.706136  0.879810  0.629191  0.701897   0.701897   532170.0
# 2  2015-08-10  0.713989  0.729854  0.636546  0.708448   0.708448   405283.0
# 3  2015-08-11  0.708087  1.131410  0.663235  1.067860   1.067860  1463100.0
# 4  2015-08-12  1.058750  1.289940  0.883608  1.217440   1.217440  2150620.0

# %%
# df = df.reset_index()
# df.head()
# Out:
#    index        Date      Open      High       Low     Close  Adj Close  \
# 0      0  2015-08-08  2.793760  2.798810  0.714725  0.753325   0.753325
# 1      1  2015-08-09  0.706136  0.879810  0.629191  0.701897   0.701897
# 2      2  2015-08-10  0.713989  0.729854  0.636546  0.708448   0.708448
# 3      3  2015-08-11  0.708087  1.131410  0.663235  1.067860   1.067860
# 4      4  2015-08-12  1.058750  1.289940  0.883608  1.217440   1.217440
#
#       Volume
# 0   674188.0
# 1   532170.0
# 2   405283.0
# 3  1463100.0
# 4  2150620.0

# %%
plt.plot(df.Close)

# %%
ma100 =  df.Close.rolling(100).mean()
ma100
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 2115    2269.132787
# 2116    2277.427599
# 2117    2286.443047
# 2118    2297.532124
# 2119    2307.482780
# Name: Close, Length: 2120, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.plot(df.Close)
plt.plot(ma100,'r')

# %%
ma200 =  df.Close.rolling(200).mean()
ma200
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 2115    1582.527753
# 2116    1593.675372
# 2117    1604.934920
# 2118    1617.199848
# 2119    1628.812739
# Name: Close, Length: 2120, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.plot(df.Close)
plt.plot(ma100,'r')
plt.plot(ma200,'g')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2120, step=1)

# %%
plt.figure(figsize=(12,6))
df.plot.line(y="Close",x="Date",color="pink")
# Out:
# <Axes: xlabel='Date'>
